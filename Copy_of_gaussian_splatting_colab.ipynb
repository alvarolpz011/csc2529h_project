# %%
# %cd /content
# !git clone --recursive https://github.com/camenduru/gaussian-splatting
# !pip install -q plyfile

# %cd /content/gaussian-splatting
# !pip install -q /content/gaussian-splatting/submodules/diff-gaussian-rasterization
# !pip install -q /content/gaussian-splatting/submodules/simple-knn

# !wget https://huggingface.co/camenduru/gaussian-splatting/resolve/main/tandt_db.zip
# !unzip tandt_db.zip

# !python train.py -s /content/gaussian-splatting/tandt/train

# !wget https://huggingface.co/camenduru/gaussian-splatting/resolve/main/GaussianViewTest.zip
# !unzip GaussianViewTest.zip
# !python render.py -m /content/gaussian-splatting/GaussianViewTest/model
# !ffmpeg -framerate 3 -i /content/gaussian-splatting/GaussianViewTest/model/train/ours_30000/renders/%05d.png -vf "pad=ceil(iw/2)*2:ceil(ih/2)*2" -c:v libx264 -r 3 -pix_fmt yuv420p /content/renders.mp4
# !ffmpeg -framerate 3 -i /content/gaussian-splatting/GaussianViewTest/model/train/ours_30000/gt/%05d.png -vf "pad=ceil(iw/2)*2:ceil(ih/2)*2" -c:v libx264 -r 3 -pix_fmt yuv420p /content/gt.mp4 -y
# Out:
# /content
# Cloning into 'gaussian-splatting'...
# remote: Enumerating objects: 603, done.
# remote: Total 603 (delta 0), reused 0 (delta 0), pack-reused 603 (from 1)
# Receiving objects: 100% (603/603), 2.09 MiB | 12.16 MiB/s, done.
# Resolving deltas: 100% (349/349), done.
# Submodule 'SIBR_viewers' (https://gitlab.inria.fr/sibr/sibr_core) registered for path 'SIBR_viewers'
# Submodule 'submodules/diff-gaussian-rasterization' (https://github.com/graphdeco-inria/diff-gaussian-rasterization) registered for path 'submodules/diff-gaussian-rasterization'
# Submodule 'submodules/simple-knn' (https://gitlab.inria.fr/bkerbl/simple-knn.git) registered for path 'submodules/simple-knn'
# Cloning into '/content/gaussian-splatting/SIBR_viewers'...
# ...
# remote: Enumerating objects: 3293, done.
# remote: Counting objects: 100% (322/322), done.
# remote: Compressing objects: 100% (174/174), done.
# remote: Total 3293 (delta 171), reused 280 (delta 148), pack-reused 2971 (from 1)
# ...

# %%
# %cd /content
# !git clone --recursive https://github.com/camenduru/gaussian-splatting
# %cd /content/gaussian-splatting
# Out:
# /content
# fatal: destination path 'gaussian-splatting' already exists and is not an empty directory.
# /content/gaussian-splatting

# %%
# !pip install -q ninja plyfile tqdm matplotlib opencv-python
# !pip install -q torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 180.7/180.7 kB 3.8 MB/s eta 0:00:00

# %%
# !pip install ./submodules/diff-gaussian-rasterization
# !CUDA_HOME=/usr/local/cuda pip install ./submodules/simple-knn --verbose
# Out:
# Processing ./submodules/diff-gaussian-rasterization
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for diff_gaussian_rasterization: filename=diff_gaussian_rasterization-0.0.0-cp312-cp312-linux_x86_64.whl size=3433268 sha256=26eb20177d3f99623a651bc993431f9f81663292818ada5a3ab0609af266f237
#   Stored in directory: /root/.cache/pip/wheels/01/e0/e8/f40a1cd6a1d5760cbd3036081bdad5b36c41fc11c786d4a404
# Successfully built diff_gaussian_rasterization
# ...
#   Attempting uninstall: diff_gaussian_rasterization
#     Found existing installation: diff_gaussian_rasterization 0.0.0
#     Uninstalling diff_gaussian_rasterization-0.0.0:
#       Successfully uninstalled diff_gaussian_rasterization-0.0.0
# ...
# Using pip 24.1.2 from /usr/local/lib/python3.12/dist-packages/pip (python 3.12)
# Processing ./submodules/simple-knn
#   Running command python setup.py egg_info
#   running egg_info
#   creating /tmp/pip-pip-egg-info-pi60jtyg/simple_knn.egg-info
# ...

# %%
# %cd /content/gaussian-splatting/submodules/simple-knn
# Out:
# /content/gaussian-splatting/submodules/simple-knn

# %%
# Insert missing include
# !sed -i '1i #include <float.h>' simple_knn.cu

# %%
# %cd /content/gaussian-splatting
# !CUDA_HOME=/usr/local/cuda pip install ./submodules/simple-knn --verbose
# Out:
# /content/gaussian-splatting
# Using pip 24.1.2 from /usr/local/lib/python3.12/dist-packages/pip (python 3.12)
# Processing ./submodules/simple-knn
#   Running command python setup.py egg_info
#   running egg_info
#   creating /tmp/pip-pip-egg-info-j36aeaio/simple_knn.egg-info
#   writing /tmp/pip-pip-egg-info-j36aeaio/simple_knn.egg-info/PKG-INFO
#   writing dependency_links to /tmp/pip-pip-egg-info-j36aeaio/simple_knn.egg-info/dependency_links.txt
#   writing top-level names to /tmp/pip-pip-egg-info-j36aeaio/simple_knn.egg-info/top_level.txt
#   writing manifest file '/tmp/pip-pip-egg-info-j36aeaio/simple_knn.egg-info/SOURCES.txt'
#   reading manifest file '/tmp/pip-pip-egg-info-j36aeaio/simple_knn.egg-info/SOURCES.txt'
#   writing manifest file '/tmp/pip-pip-egg-info-j36aeaio/simple_knn.egg-info/SOURCES.txt'
#   Preparing metadata (setup.py) ... done
# ...
#   Running command python setup.py bdist_wheel
#   running bdist_wheel
#   running build
#   running build_ext
# ...

# %%
# !wget -q https://huggingface.co/camenduru/gaussian-splatting/resolve/main/tandt_db.zip
# !unzip -q tandt_db.zip
# Out:
# replace db/drjohnson/images/IMG_6292.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
# !python train.py -s /content/gaussian-splatting/tandt/train
# Out:
# 2025-11-01 14:36:51.386395: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-01 14:36:51.403180: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1762007811.424237    5746 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1762007811.430728    5746 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# %cd /content/gaussian-splatting
# !python render.py -m /content/gaussian-splatting/output/4993f0af-9
# Out:
# /content/gaussian-splatting
# Looking for config file in /content/gaussian-splatting/output/4993f0af-9/cfg_args
# Config file found: /content/gaussian-splatting/output/4993f0af-9/cfg_args
# Rendering /content/gaussian-splatting/output/4993f0af-9
# Loading trained model at iteration 30000 [01/11 15:01:36]
# Reading camera 301/301 [01/11 15:01:38]
# Loading Training Cameras [01/11 15:01:38]
# Loading Test Cameras [01/11 15:01:42]
# Rendering progress: 100% 301/301 [02:12<00:00,  2.27it/s]
# Rendering progress: 0it [00:00, ?it/s]

# %%
# !ffmpeg -framerate 12 \
  -i /content/gaussian-splatting/output/4993f0af-9/train/ours_30000/renders/%05d.png \
  -vf "pad=ceil(iw/2)*2:ceil(ih/2)*2" -c:v libx264 -r 30 -pix_fmt yuv420p /content/gs_render.mp4 -y
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
# ...
