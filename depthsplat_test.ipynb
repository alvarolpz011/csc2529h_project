# %% [markdown]
# ## INSTALLING DIFF GAUSSIAN RASTERIZATION

# %%
# %cd /content
# !git clone --recursive https://github.com/camenduru/gaussian-splatting
# !pip install -q plyfile

# %cd /content/gaussian-splatting
# !pip install -q /content/gaussian-splatting/submodules/diff-gaussian-rasterization
# !pip install -q /content/gaussian-splatting/submodules/simple-knn
# Out:
# /content
# Cloning into 'gaussian-splatting'...
# remote: Enumerating objects: 603, done.
# remote: Total 603 (delta 0), reused 0 (delta 0), pack-reused 603 (from 1)
# Receiving objects: 100% (603/603), 2.09 MiB | 5.64 MiB/s, done.
# Resolving deltas: 100% (347/347), done.
# Submodule 'SIBR_viewers' (https://gitlab.inria.fr/sibr/sibr_core) registered for path 'SIBR_viewers'
# Submodule 'submodules/diff-gaussian-rasterization' (https://github.com/graphdeco-inria/diff-gaussian-rasterization) registered for path 'submodules/diff-gaussian-rasterization'
# Submodule 'submodules/simple-knn' (https://gitlab.inria.fr/bkerbl/simple-knn.git) registered for path 'submodules/simple-knn'
# Cloning into '/content/gaussian-splatting/SIBR_viewers'...
# ...
# remote: Enumerating objects: 3293, done.
# remote: Counting objects: 100% (322/322), done.
# remote: Compressing objects: 100% (174/174), done.
# remote: Total 3293 (delta 171), reused 280 (delta 148), pack-reused 2971 (from 1)
# ...

# %%
# %cd /content
# !git clone --recursive https://github.com/camenduru/gaussian-splatting
# %cd /content/gaussian-splatting
# Out:
# /content
# fatal: destination path 'gaussian-splatting' already exists and is not an empty directory.
# /content/gaussian-splatting

# %%
# !pip install -q ninja plyfile tqdm matplotlib opencv-python
# !pip install -q torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 180.7/180.7 kB 7.1 MB/s eta 0:00:00

# %%
# !pip install ./submodules/diff-gaussian-rasterization
# Out:
# Processing ./submodules/diff-gaussian-rasterization
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for diff_gaussian_rasterization: filename=diff_gaussian_rasterization-0.0.0-cp312-cp312-linux_x86_64.whl size=3438259 sha256=b21cd80aca2edbc4ddb2345790d47a9845ab7616056a5fff477d25495a6fc945
#   Stored in directory: /root/.cache/pip/wheels/01/e0/e8/f40a1cd6a1d5760cbd3036081bdad5b36c41fc11c786d4a404
# Successfully built diff_gaussian_rasterization
# ...
#   Attempting uninstall: diff_gaussian_rasterization
#     Found existing installation: diff_gaussian_rasterization 0.0.0
#     Uninstalling diff_gaussian_rasterization-0.0.0:
#       Successfully uninstalled diff_gaussian_rasterization-0.0.0
# ...

# %% [markdown]
# ## ^^^ HASTA AQUI ES LO DE MOE

# %%
# %cd /content
# !git clone --recursive https://github.com/cvg/depthsplat.git
# %cd depthsplat
# Out:
# /content
# Cloning into 'depthsplat'...
# remote: Enumerating objects: 296, done.
# remote: Counting objects: 100% (131/131), done.
# remote: Compressing objects: 100% (80/80), done.
# remote: Total 296 (delta 84), reused 51 (delta 51), pack-reused 165 (from 1)
# Receiving objects: 100% (296/296), 2.32 MiB | 6.93 MiB/s, done.
# Resolving deltas: 100% (109/109), done.
# /content/depthsplat

# %%
# !wget https://huggingface.co/datasets/haofeixu/depthsplat/resolve/main/dl3dv_960p_test_subset.zip
# !mkdir datasets
# !mv dl3dv_960p_test_subset.zip datasets/dl3dv.zip
# !unzip datasets/dl3dv.zip -d datasets/
# !rm datasets/dl3dv.zip
# Out:
# --2025-11-01 20:46:14--  https://huggingface.co/datasets/haofeixu/depthsplat/resolve/main/dl3dv_960p_test_subset.zip
# Resolving huggingface.co (huggingface.co)... 18.164.174.17, 18.164.174.23, 18.164.174.55, ...
# Connecting to huggingface.co (huggingface.co)|18.164.174.17|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# !pip install torch==2.4.0 torchvision==0.19.0 --index-url https://download.pytorch.org/whl/cu124
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu124
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 797.2/797.2 MB 652.2 kB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 90.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.7/24.7 MB 103.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.4/883.4 kB 68.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 128.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.0/363.0 MB 4.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 1.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 14.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.4/128.4 MB 7.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 2.3 MB/s eta 0:00:00
# ...

# %%
# !pip install \
beartype==0.18.5 \
colorama==0.4.6 \
colorspacious==1.1.2 \
dacite==1.8.1 \
e3nn==0.5.1 \
einops==0.8.0 \
hydra-core==1.3.2 \
jaxtyping==0.2.33 \
lpips==0.1.4 \
matplotlib==3.9.1 \
moviepy==1.0.3 \
numpy \
opencv_python==4.11.0.86 \
Pillow==10.4.0 \
plyfile==1.1 \
pytorch_lightning==2.4.0 \
scikit-image==0.24.0 \
sk-video==1.1.10 \
tabulate==0.9.0 \
tqdm==4.66.4 \
wandb==0.17.7 \
xformers==0.0.27.post2
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 6.0 MB/s eta 0:00:00
# ...
# WARNING: The candidate selected for download or install is a yanked version: 'matplotlib' candidate (version 3.9.1 at https://files.pythonhosted.org/packages/0d/cb/78283ec2ded91fb74a2ae9ae93f91a897fa578fa78c8c271a7c147f6b8d6/matplotlib-3.9.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (from https://pypi.org/simple/matplotlib/) (requires-python:>=3.9))
# ...

# %%
# %cd /content/gaussian-splatting/submodules/diff-gaussian-rasterization
# !rm -rf build dist *.egg-info
# !pip install --force-reinstall --no-cache-dir .
# Out:
# /content/gaussian-splatting/submodules/diff-gaussian-rasterization
# Processing /content/gaussian-splatting/submodules/diff-gaussian-rasterization
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for diff_gaussian_rasterization: filename=diff_gaussian_rasterization-0.0.0-cp312-cp312-linux_x86_64.whl size=3305832 sha256=821801765de8852c8f8d4f6ac0367123bd8880963a640b66309f2863ef2a00df
#   Stored in directory: /tmp/pip-ephem-wheel-cache-i3jbzmzj/wheels/01/e0/e8/f40a1cd6a1d5760cbd3036081bdad5b36c41fc11c786d4a404
# Successfully built diff_gaussian_rasterization
# ...
#   Attempting uninstall: diff_gaussian_rasterization
#     Found existing installation: diff_gaussian_rasterization 0.0.0
#     Uninstalling diff_gaussian_rasterization-0.0.0:
#       Successfully uninstalled diff_gaussian_rasterization-0.0.0
# ...

# %%
# Move to repo root
# %cd /content/depthsplat

# download pretrained model
# !mkdir pretrained
# %cd pretrained
# !wget https://huggingface.co/haofeixu/depthsplat/resolve/main/depthsplat-gs-small-re10kdl3dv-448x768-randview4-10-c08188db.pth
# !wget https://huggingface.co/haofeixu/depthsplat/resolve/main/depthsplat-depth-small-352x640-randview2-8-e807bd82.pth

# %cd /content/depthsplat

# Silence XDG/ALSA noise (useful on Colab)
import os
os.environ['XDG_RUNTIME_DIR'] = '/tmp/runtime-root'
os.makedirs('/tmp/runtime-root', exist_ok=True)
# optional: force ffmpeg to not use audio
os.environ['FFMPEG_NOPRUNED'] = '1'
os.environ['SDL_AUDIODRIVER'] = 'dummy'

# Run the program — note single quotes around overrides with brackets
# !python -m src.main +experiment=dl3dv \
  'dataset.roots=["datasets/dl3dv"]' \
  'dataset.image_shape=[512,960]' \
  'dataset.ori_image_shape=[540,960]' \
  'model.encoder.upsample_factor=8' \
  'model.encoder.lowest_feature_resolution=8' \
  'model.encoder.gaussian_adapter.gaussian_scale_max=0.1' \
  'checkpointing.pretrained_model=pretrained/depthsplat-gs-small-re10kdl3dv-448x768-randview4-10-c08188db.pth' \
  mode=test \
  'dataset.view_sampler=evaluation' \
  '+dataset.view_sampler.num_context_views=12' \
  '+dataset.view_sampler.index_path=assets/dl3dv_start_0_distance_100_ctx_12v_video.json' \
  'test.save_video=true' \
  'test.stablize_camera=true' \
  'test.compute_scores=false' \
  'test.render_chunk_size=10' \
  'output_dir=outputs/depthsplat-dl3dv-512x960'
# Out:
# /content/depthsplat
# /content/depthsplat/pretrained
# --2025-11-01 21:09:36--  https://huggingface.co/haofeixu/depthsplat/resolve/main/depthsplat-gs-small-re10kdl3dv-448x768-randview4-10-c08188db.pth
# Resolving huggingface.co (huggingface.co)... 18.164.174.17, 18.164.174.118, 18.164.174.23, ...
# Connecting to huggingface.co (huggingface.co)|18.164.174.17|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...
